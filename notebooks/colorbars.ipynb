# %% [markdown]
# # Plot colorbars for paper

# %%
import ProbabilisticParcellation.evaluate as ev
import ProbabilisticParcellation.util as ut
import ProbabilisticParcellation.export_atlas as ea
import ProbabilisticParcellation.hierarchical_clustering as hc
import ProbabilisticParcellation.scripts.atlas_paper.evaluate_atlas as eva
import Functional_Fusion.dataset as ds
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as col
import seaborn as sb
import SUITPy as suit
import nitools as nt
import nibabel as nb
import numpy as np
import os

# %%
suit_dir = ut.base_dir + '/Atlases/tpl-SUIT/'

# %%
figsize = (8, 8)
_, cmap, labels = nt.read_lut(suit_dir +
                              'atl-NettekovenSym32.lut')

# %%
plt.figure(figsize=(10,2))
ax=plt.subplot(111)
ax.set_xlim(0,160)
ax.set_ylim(-1,1)
ax.set_axis_off()
hc.draw_cmap(ax,col.ListedColormap(cmap*0.9), np.arange(16),sym=False,height=0.6)
plt.savefig('Nettekoven_colorbar.pdf')

# %% [markdown]
# # Inferno, reds color bars

# %%
# get inferno color map
cmap = matplotlib.cm.get_cmap('inferno')

plt.figure(figsize=(10, 2))
ax = plt.subplot(111)
ax.set_xlim(0, 1.0)
ax.set_ylim(-1, 1)
# ax.set_axis_off()
norm = matplotlib.colors.Normalize(vmin=0, vmax=1)
cb1 = matplotlib.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                spacing='proportional',
                                orientation='horizontal')
# Rotate ticks by 90 degrees
# Get xticklabels and make ticks bigger
ticks = cb1.ax.get_xticklabels()
cb1.ax.set_xticklabels(ticks, rotation=-90, fontsize=20)
plt.savefig(ut.figure_dir + 'colorbar_inferno.pdf',
            dpi=300, bbox_inches="tight")
# Out:
# /var/folders/y1/13zjm1t50ms6ds24c69y7vx40000gn/T/ipykernel_58019/4093934729.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cb1.ax.set_xticklabels(ticks, rotation=-90, fontsize=20)

# %% [markdown]
# # Connectivity colour bars
# ## Connectivity summary

# %%
# get inferno color map
cmap = matplotlib.cm.get_cmap('RdBu_r')

plt.figure(figsize=(10, 2))
ax = plt.subplot(111)
ax.set_xlim(0, 1.0)
ax.set_ylim(-1, 1)
# ax.set_axis_off()
norm = matplotlib.colors.Normalize(vmin=-0.0011790506635797479, vmax=0.0011790506635797479)
cb1 = matplotlib.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                spacing='proportional',
                                orientation='horizontal')
# Rotate ticks by 90 degrees
# Get xticklabels and make ticks bigger
ticks = cb1.ax.get_xticklabels()
cb1.ax.set_xticklabels(ticks, rotation=-90, fontsize=20)
plt.savefig(ut.figure_dir + 'colorbar_connectivity_summary.pdf',
            dpi=300, bbox_inches="tight")
# Out:
# /var/folders/y1/13zjm1t50ms6ds24c69y7vx40000gn/T/ipykernel_93473/354327672.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = matplotlib.cm.get_cmap('RdBu_r')
# /var/folders/y1/13zjm1t50ms6ds24c69y7vx40000gn/T/ipykernel_93473/354327672.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cb1.ax.set_xticklabels(ticks, rotation=-90, fontsize=20)

# %%
# get inferno color map
cmap = matplotlib.cm.get_cmap('RdBu_r')

plt.figure(figsize=(10, 2))
ax = plt.subplot(111)
ax.set_xlim(0, 1.0)
ax.set_ylim(-1, 1)
# ax.set_axis_off()
norm = matplotlib.colors.Normalize(vmin=-0.45651898902177857, vmax=0.45651898902177857)
cb1 = matplotlib.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                spacing='proportional',
                                orientation='horizontal')
# Rotate ticks by 90 degrees
# Get xticklabels and make ticks bigger
ticks = cb1.ax.get_xticklabels()
cb1.ax.set_xticklabels(ticks, rotation=-90, fontsize=20)
plt.savefig(ut.figure_dir + 'colorbar_feature_matrix_summary.pdf',
            dpi=300, bbox_inches="tight")
# Out:
# /var/folders/y1/13zjm1t50ms6ds24c69y7vx40000gn/T/ipykernel_93473/898564733.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = matplotlib.cm.get_cmap('RdBu_r')
# /var/folders/y1/13zjm1t50ms6ds24c69y7vx40000gn/T/ipykernel_93473/898564733.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cb1.ax.set_xticklabels(ticks, rotation=-90, fontsize=20)

# %%
# get inferno color map
cmap = matplotlib.cm.get_cmap('RdBu_r')

plt.figure(figsize=(10, 2))
ax = plt.subplot(111)
ax.set_xlim(0, 1.0)
ax.set_ylim(-1, 1)
# ax.set_axis_off()
norm = matplotlib.colors.Normalize(vmin=-0.002, vmax=0.002)
cb1 = matplotlib.colorbar.ColorbarBase(ax, cmap=cmap,
                                norm=norm,
                                spacing='proportional',
                                orientation='horizontal')
# Rotate ticks by 90 degrees
# Get xticklabels and make ticks bigger
ticks = cb1.ax.get_xticklabels()
cb1.ax.set_xticklabels(ticks, rotation=-90, fontsize=20)
plt.savefig(ut.figure_dir + 'colorbar_connectivity_weights.pdf',
            dpi=300, bbox_inches="tight")
# Out:
# /var/folders/y1/13zjm1t50ms6ds24c69y7vx40000gn/T/ipykernel_93473/2192690368.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = matplotlib.cm.get_cmap('RdBu_r')
# /var/folders/y1/13zjm1t50ms6ds24c69y7vx40000gn/T/ipykernel_93473/2192690368.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cb1.ax.set_xticklabels(ticks, rotation=-90, fontsize=20)
