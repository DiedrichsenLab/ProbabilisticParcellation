# %%
from pathlib import Path
import pandas as pd
import numpy as np
import nibabel as nb
import SUITPy as suit
import matplotlib.pyplot as plt
import seaborn as sb
import Functional_Fusion.atlas_map as am
from Functional_Fusion.dataset import *
import Functional_Fusion.matrix as matrix
import pickle
import sys
sys.path.append("..")
from ProbabilisticParcellation.util import *

base_dir = '/Volumes/diedrichsen_data$/data/FunctionalFusion'
if not Path(base_dir).exists():
    base_dir = '/srv/diedrichsen/data/FunctionalFusion'

# %% [markdown]
# This notebook plots some of the different parcellations

# %% [markdown]
# ### Get the K=10 parcellations
#
# # Parcellating individual datasets

# %%
model_name = ['asym_Md_space-MNISymC3_K-10',
                  'asym_Po_space-MNISymC3_K-10',
                  'asym_Ni_space-MNISymC3_K-10',
                  'asym_Ib_space-MNISymC3_K-10',
                  'asym_Hc_space-MNISymC3_K-10']
fig = plt.figure(figsize=(20,10))
plot_model_parcel(model_name,[2,3])

# %% [markdown]
# ## Parcellating merged datasets

# %%
model_name = ['asym_MdPoNiIb_space-MNISymC3_K-10',
                  'asym_MdPoNiIbHc_space-MNISymC3_K-10']
fig = plt.figure(figsize=(20,10))
plot_model_parcel(model_name,[1,2])

# %%
model_name = ['Models_01/asym_Hc_space-MNISymC3_K-10',
              'Models_02/asym_Hc_space-MNISymC3_K-10']
fig = plt.figure(figsize=(20,10))
plot_model_parcel(model_name,[1,2])
