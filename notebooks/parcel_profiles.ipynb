# %%
from pathlib import Path
import pandas as pd
import numpy as np
import nibabel as nb
import SUITPy as suit
import matplotlib.pyplot as plt
import seaborn as sb
import Functional_Fusion.atlas_map as am
from Functional_Fusion.dataset import *
import Functional_Fusion.matrix as matrix
import pickle
import sys
sys.path.append("..")
from ProbabilisticParcellation.util import *

base_dir = '/Volumes/diedrichsen_data$/data/FunctionalFusion'
if not Path(base_dir).exists():
    base_dir = '/srv/diedrichsen/data/FunctionalFusion'

# %% [markdown]
# This notebook plots task profiles for the K=34 parcellation.

# %% [markdown]
# ### Get the K=34 parcellations
#
# # Parcellating individual datasets

# %%
model_name = ['Models_01/asym_Md_space-MNISymC3_K-10',
                  'Models_01/asym_Po_space-MNISymC3_K-14',
                  'Models_01/asym_Ni_space-MNISymC3_K-18',
                  'Models_01/asym_Ni_space-MNISymC3_K-22',
                  'Models_01/asym_Ib_space-MNISymC3_K-26',
                  'Models_01/asym_Hc_space-MNISymC3_K-30',
                  'Models_01/asym_Hc_space-MNISymC3_K-34']
fig = plt.figure(figsize=(20,10))
plot_model_parcel(model_name,[3,3])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [10], line 9
#       1 model_name = ['Models_01/asym_Md_space-MNISymC3_K-10',
#       2                   'Models_01/asym_Po_space-MNISymC3_K-14',
#       3                   'Models_01/asym_Ni_space-MNISymC3_K-18',
#    (...)
#       6                   'Models_01/asym_Hc_space-MNISymC3_K-30',
#       7                   'Models_01/asym_Hc_space-MNISymC3_K-34']
#       8 fig = plt.figure(figsize=(20,10))
# ----> 9 plot_model_parcel(model_name,[3,3])
#
# File ~/Python/ProbabilisticParcellation/util.py:173, in plot_model_parcel(model_names, grid, cmap)
#     171 # Extracts the data
#     172 for i,mn in enumerate(model_names):
# --> 173     info,model = load_batch_best(mn)
#     174     Prop = model.marginal_prob()
#     175     parcel.append(np.argmax(Prop,axis=0)+1) # Get winner take all
#
# ...

# %%
model_name = ['Models_01/asym_MdPoNiIbHc_space-MNISymC3_K-10',
                  'Models_01/asym_MdPoNiIbHc_space-MNISymC3_K-20',
                  'Models_01/asym_Ni_space-MNISymC3_K-34',
                  'Models_01/asym_Ib_space-MNISymC3_K-34',
                  'Models_01/asym_Hc_space-MNISymC3_K-34']
fig = plt.figure(figsize=(20,10))
plot_model_parcel(model_name,[2,3], render='plotly')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [11], line 7
#       1 model_name = ['Models_01/asym_MdPoNiIbHc_space-MNISymC3_K-10',
#       2                   'Models_01/asym_MdPoNiIbHc_space-MNISymC3_K-20',
#       3                   'Models_01/asym_Ni_space-MNISymC3_K-34',
#       4                   'Models_01/asym_Ib_space-MNISymC3_K-34',
#       5                   'Models_01/asym_Hc_space-MNISymC3_K-34']
#       6 fig = plt.figure(figsize=(20,10))
# ----> 7 plot_model_parcel(model_name,[2,3], render='plotly')
#
# TypeError: plot_model_parcel() got an unexpected keyword argument 'render'

# %%
model_name = ['Models_01/asym_MdPoNiIbHc_space-MNISymC3_K-20']
fig = plt.figure(figsize=(20,10))
plot_model_parcel(model_name,[1,1])

# %%
model_name = ['Models_01/asym_MdPoNiIbHc_space-MNISymC3_K-34']
fig = plt.figure(figsize=(20,10))
plot_model_parcel(model_name,[1,1])

# %% [markdown]
# ### Task Profiles for symmetric parcels
