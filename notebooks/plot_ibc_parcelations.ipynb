# %%
from pathlib import Path
import pandas as pd
import numpy as np
import nibabel as nb
import SUITPy as suit
import matplotlib.pyplot as plt
import seaborn as sb
import Functional_Fusion.atlas_map as am
from Functional_Fusion.dataset import *
import Functional_Fusion.matrix as matrix
import pickle
import sys
sys.path.append("..")
from evaluate import *

base_dir = '/Volumes/diedrichsen_data$/data/FunctionalFusion'
if not Path(base_dir).exists():
    base_dir = '/srv/diedrichsen/data/FunctionalFusion'

# %% [markdown]
# This notebook plots the different IBC parcellations

# %% [markdown]
# ### Get the K=10 parcellations for IBC datset

# %%
model_name = ['ibc_selected_sessions/asym_Ib_space-MNISymC3_K-10_ses-all']
fig = plt.figure(figsize=(10,8))
plot_parcel_flat_best(model_name,[1,1])
# Out:
# /Users/callithrix/Python/SUITPy/SUITPy/flatmap.py:234: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mapped_data[:,index[v]:index[v+1]],_ = ss.mode(data,axis=0)
# ...

# %% [markdown]
# ## IBC Parcellation estimated on individual sessions

# %%
model_name = ['ibc_selected_sessions/asym_Ib_space-MNISymC3_K-10_ses-hcp1',
              'ibc_selected_sessions/asym_Ib_space-MNISymC3_K-10_ses-hcp2',
              'ibc_selected_sessions/asym_Ib_space-MNISymC3_K-10_ses-tom',
              'ibc_selected_sessions/asym_Ib_space-MNISymC3_K-10_ses-rsvplang']
fig = plt.figure(figsize=(10,8))
plot_parcel_flat_best(model_name,[2,2])
# Out:
# /Users/callithrix/Python/SUITPy/SUITPy/flatmap.py:234: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mapped_data[:,index[v]:index[v+1]],_ = ss.mode(data,axis=0)
# ...

# %%
model_name = ['ibc_selected_sessions/asym_Ib_space-MNISymC3_K-10_ses-mtt1',
              'ibc_selected_sessions/asym_Ib_space-MNISymC3_K-10_ses-mtt2',
              'ibc_selected_sessions/asym_Ib_space-MNISymC3_K-10_ses-spatialnavigation',
              'ibc_selected_sessions/asym_Ib_space-MNISymC3_K-10_ses-lyon1']
fig = plt.figure(figsize=(10,8))
plot_parcel_flat_best(model_name,[2,2])
# Out:
# /Users/callithrix/Python/SUITPy/SUITPy/flatmap.py:234: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mapped_data[:,index[v]:index[v+1]],_ = ss.mode(data,axis=0)
# ...

# %% [markdown]
# ### Add IBC Parcellation

# %%
model_name = ['asym_Md_space-MNISymC3_K-10',
                'asym_Po_space-MNISymC3_K-10',
                'asym_Ni_space-MNISymC3_K-10',
                'asym_Ib_space-MNISymC3_K-10',
                'asym_MdPoNiIb_space-MNISymC3_K-10']
fig = plt.figure(figsize=(10,8))
plot_parcel_flat_best(model_name,[3,2])
# Out:
# /Users/callithrix/Python/SUITPy/SUITPy/flatmap.py:234: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mapped_data[:,index[v]:index[v+1]],_ = ss.mode(data,axis=0)
# ...

# %%
model_name = ['asym_Md_space-MNISymC3_K-10',
                'asym_MdPoNiIb_space-MNISymC3_K-10']
fig = plt.figure(figsize=(10,8))
plot_parcel_flat_best(model_name,[1,2])
# Out:
# /Users/callithrix/Python/SUITPy/SUITPy/flatmap.py:234: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mapped_data[:,index[v]:index[v+1]],_ = ss.mode(data,axis=0)
# ...
