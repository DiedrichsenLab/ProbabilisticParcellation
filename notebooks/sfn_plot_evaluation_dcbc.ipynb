# %% [markdown]
# # DCBC evaluation

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import sys

base_dir = '/Volumes/diedrichsen_data$/data/FunctionalFusion'
if not Path(base_dir).exists():
    base_dir = '/srv/diedrichsen/data/FunctionalFusion'

# %% [markdown]
# This notebook plots the DCBC and cosine error evaluation of the different parcellations

# %% [markdown]
# ## Evaluation on old parcellations

# %%
D=pd.read_csv(base_dir + '/Models/eval_dcbc_group.tsv',sep='\t')
D['name']=[s.split('_')[0] for s in D.model_name]
sb.barplot(data=D,x='name',y='dcbc')
# Out:
# <AxesSubplot: xlabel='name', ylabel='dcbc'>

# %%
D
# Out:
#                                   model_name test_data  subj_num      dcbc  \
# 0                asym_Md_space-MNISymC3_K-10      Mdtb         0  0.101467
# 1                asym_Md_space-MNISymC3_K-10      Mdtb         1  0.096007
# 2                asym_Md_space-MNISymC3_K-10      Mdtb         2  0.051763
# 3                asym_Md_space-MNISymC3_K-10      Mdtb         3  0.205131
# 4                asym_Md_space-MNISymC3_K-10      Mdtb         4  0.101393
# ..                                       ...       ...       ...       ...
# 139  atl-Ji10_space-MNI152NLin2009cSymC_dseg      Mdtb        19  0.086433
# 140  atl-Ji10_space-MNI152NLin2009cSymC_dseg      Mdtb        20  0.097446
# 141  atl-Ji10_space-MNI152NLin2009cSymC_dseg      Mdtb        21  0.073917
# 142  atl-Ji10_space-MNI152NLin2009cSymC_dseg      Mdtb        22  0.034162
# 143  atl-Ji10_space-MNI152NLin2009cSymC_dseg      Mdtb        23  0.098783
#
#          name
# 0        asym
# 1        asym
# 2        asym
# 3        asym
# 4        asym
# ..        ...
# 139  atl-Ji10
# 140  atl-Ji10
# 141  atl-Ji10
# 142  atl-Ji10
# 143  atl-Ji10
#
# [144 rows x 5 columns]

# %% [markdown]
# ## Evaluation on the new parcellations

# %%
# Load evaluation results
type = ['sym','asym']
K = [10,20,34]
D = pd.DataFrame()
for t in type:
    for k in K: 
        fname = base_dir + f'/Models/Evaluation_01/eval_dcbc_{t}_K-{k}.tsv'
        dcbc = pd.read_csv(fname, sep='\t')
        dcbc['type']=[t]*dcbc.shape[0]
        D=pd.concat([D,dcbc],ignore_index=True)
D
# Out:
#       model_name     atlas   K                                  train_data  \
# 0              0  MNISymC3  10                                    ['Mdtb']
# 1              0  MNISymC3  10                                    ['Mdtb']
# 2              0  MNISymC3  10                                    ['Mdtb']
# 3              0  MNISymC3  10                                    ['Mdtb']
# 4              0  MNISymC3  10                                    ['Mdtb']
# ...          ...       ...  ..                                         ...
# 4195           6  MNISymC3  34  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']
# 4196           6  MNISymC3  34  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']
# 4197           6  MNISymC3  34  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']
# 4198           6  MNISymC3  34  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']
# 4199           6  MNISymC3  34  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']
#
#       train_loglik test_data indivtrain_ind  indivtrain_val  subj_num  \
# 0     1.115685e+07      Mdtb           half               1         0
# 1     1.115685e+07      Mdtb           half               1         1
# 2     1.115685e+07      Mdtb           half               1         2
# 3     1.115685e+07      Mdtb           half               1         3
# 4     1.115685e+07      Mdtb           half               1         4
# ...            ...       ...            ...             ...       ...
# 4195  1.483814e+08       Ibc           half               2         7
# 4196  1.483814e+08       Ibc           half               2         8
# 4197  1.483814e+08       Ibc           half               2         9
# 4198  1.483814e+08       Ibc           half               2        10
# 4199  1.483814e+08       Ibc           half               2        11
#
#       dcbc_group  dcbc_indiv  type
# 0       0.091854    0.111048   sym
# 1       0.095631    0.167012   sym
# 2       0.026171    0.048825   sym
# 3       0.209580    0.296363   sym
# 4       0.134436    0.125377   sym
# ...          ...         ...   ...
# 4195    0.021919    0.078985  asym
# 4196    0.026541    0.031448  asym
# 4197    0.036939    0.071233  asym
# 4198    0.028013    0.057569  asym
# 4199    0.036717    0.055876  asym
#
# [4200 rows x 12 columns]

# %% [markdown]
# ### DCBC for group arrangement model: Train and test
# Error bars indicate variation in DCBC across subjects (across all four models)

# %%
plt.figure(figsize=(15,8))

sb.barplot(data=D, x="test_data", y="dcbc_group", hue="train_data")
# sb.barplot(data=dcbc, x="train_data", y="dcbc", hue="test_data")
# Out:
# <AxesSubplot: xlabel='test_data', ylabel='dcbc_group'>

# %% [markdown]
# ### Group DCBC as a function of K

# %%
plt.figure(figsize=(15,6))
T= D[(D.train_data=="['Mdtb']") | \
     (D.train_data=="['Mdtb' 'Pontine' 'Nishimoto' 'Ibc']")]
sb.lineplot(data=T,x='K',hue='train_data',style='type',y='dcbc_group')
# Out:
# <AxesSubplot: xlabel='K', ylabel='dcbc_group'>

# %% [markdown]
# ### DCBC for individual parcellations

# %%
plt.figure(figsize=(15,8))

sb.barplot(data=D, x="test_data", y="dcbc_indiv", hue="train_data")
# sb.barplot(data=dcbc, x="train_data", y="dcbc")
# Out:
# <AxesSubplot: xlabel='test_data', ylabel='dcbc_indiv'>

# %%
### Compare results to DCBC for Model 04

# %%
# Load evaluation results
files = ['sym_K-34_HCPw_sym.tsv', 'sym_K-34_task.tsv', 'asym_K-34_HCPw_asym.tsv', 'sym_K-10_task_sym.tsv']

D4 = pd.DataFrame()
for file in files:
        fname = base_dir + '/Models/Evaluation_04/eval_dcbc_' + file
        dcbc = pd.read_csv(fname, sep='\t')
        dcbc['type']=[file.split('_K')[0]]*dcbc.shape[0]
        D4=pd.concat([D4,dcbc],ignore_index=True)
D4
# Out:
#              model_name     atlas   K  \
# 0     sym_MdPoNiIbHc_00  MNISymC3  34
# 1     sym_MdPoNiIbHc_00  MNISymC3  34
# 2     sym_MdPoNiIbHc_00  MNISymC3  34
# 3     sym_MdPoNiIbHc_00  MNISymC3  34
# 4     sym_MdPoNiIbHc_00  MNISymC3  34
# ...                 ...       ...  ..
# 1895     sym_MdPoNiIbHc  MNISymC3  10
# 1896     sym_MdPoNiIbHc  MNISymC3  10
# 1897     sym_MdPoNiIbHc  MNISymC3  10
# 1898     sym_MdPoNiIbHc  MNISymC3  10
# 1899     sym_MdPoNiIbHc  MNISymC3  10
#
#                                       train_data  train_loglik test_data  \
# 0     ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  2.088253e+07      Mdtb
# 1     ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  2.088253e+07      Mdtb
# 2     ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  2.088253e+07      Mdtb
# 3     ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  2.088253e+07      Mdtb
# 4     ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  2.088253e+07      Mdtb
# ...                                          ...           ...       ...
# 1895  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07       Ibc
# 1896  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07       Ibc
# 1897  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07       Ibc
# 1898  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07       Ibc
# 1899  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07       Ibc
#
#      indivtrain_ind  indivtrain_val  subj_num  dcbc_group  dcbc_indiv type
# 0              half               1         0    0.056463    0.093329  sym
# 1              half               1         1    0.039947    0.163373  sym
# 2              half               1         2    0.020854    0.065715  sym
# 3              half               1         3    0.138505    0.298063  sym
# 4              half               1         4    0.110229    0.031571  sym
# ...             ...             ...       ...         ...         ...  ...
# 1895           half               2         7    0.005073    0.072268  sym
# 1896           half               2         8    0.019214    0.028462  sym
# 1897           half               2         9    0.019874    0.038692  sym
# 1898           half               2        10    0.017016    0.013996  sym
# 1899           half               2        11    0.027365    0.013786  sym
#
# [1900 rows x 12 columns]

# %%
plt.figure(figsize=(15,8))

sb.barplot(data=D4.query('type == "sym"'), x="test_data", y="dcbc_group", hue="model_name")
# sb.barplot(data=D4, x="model_name", y="dcbc_group")
# Out:
# <AxesSubplot: xlabel='test_data', ylabel='dcbc_group'>

# %% [markdown]
# # Compare asymmetric and symmetric

# %%
plt.figure(figsize=(15,8))

sb.barplot(data=D, x="test_data", y="dcbc_group", hue="type")
# Out:
# <AxesSubplot: xlabel='test_data', ylabel='dcbc_group'>

# %%
plt.figure(figsize=(15,8))

sb.barplot(data=D4, x="test_data", y="dcbc_group", hue="type")
# sb.barplot(data=D4, x="model_name", y="dcbc_group")
# Out:
# <AxesSubplot: xlabel='test_data', ylabel='dcbc_group'>

# %% [markdown]
# ## Compare Group DCBC of model 04 (asymmetric) to Group DCBC of model 01 (first plot)

# %%
D4
# Out:
#              model_name     atlas   K  \
# 0     sym_MdPoNiIbHc_00  MNISymC3  34
# 1     sym_MdPoNiIbHc_00  MNISymC3  34
# 2     sym_MdPoNiIbHc_00  MNISymC3  34
# 3     sym_MdPoNiIbHc_00  MNISymC3  34
# 4     sym_MdPoNiIbHc_00  MNISymC3  34
# ...                 ...       ...  ..
# 1895     sym_MdPoNiIbHc  MNISymC3  10
# 1896     sym_MdPoNiIbHc  MNISymC3  10
# 1897     sym_MdPoNiIbHc  MNISymC3  10
# 1898     sym_MdPoNiIbHc  MNISymC3  10
# 1899     sym_MdPoNiIbHc  MNISymC3  10
#
#                                       train_data  train_loglik test_data  \
# 0     ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  2.088253e+07      Mdtb
# 1     ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  2.088253e+07      Mdtb
# 2     ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  2.088253e+07      Mdtb
# 3     ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  2.088253e+07      Mdtb
# 4     ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  2.088253e+07      Mdtb
# ...                                          ...           ...       ...
# 1895  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07       Ibc
# 1896  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07       Ibc
# 1897  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07       Ibc
# 1898  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07       Ibc
# 1899  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07       Ibc
#
#      indivtrain_ind  indivtrain_val  subj_num  dcbc_group  dcbc_indiv type
# 0              half               1         0    0.056463    0.093329  sym
# 1              half               1         1    0.039947    0.163373  sym
# 2              half               1         2    0.020854    0.065715  sym
# 3              half               1         3    0.138505    0.298063  sym
# 4              half               1         4    0.110229    0.031571  sym
# ...             ...             ...       ...         ...         ...  ...
# 1895           half               2         7    0.005073    0.072268  sym
# 1896           half               2         8    0.019214    0.028462  sym
# 1897           half               2         9    0.019874    0.038692  sym
# 1898           half               2        10    0.017016    0.013996  sym
# 1899           half               2        11    0.027365    0.013786  sym
#
# [1900 rows x 12 columns]

# %%
D4.query( ' K == 10 & test_data == "Mdtb"  ')
# D.query( '  test_data == "Mdtb"  ')
# Out:
#           model_name     atlas   K  \
# 1200          sym_Md  MNISymC3  10
# 1201          sym_Md  MNISymC3  10
# 1202          sym_Md  MNISymC3  10
# 1203          sym_Md  MNISymC3  10
# 1204          sym_Md  MNISymC3  10
# ...              ...       ...  ..
# 1531  sym_MdPoNiIbHc  MNISymC3  10
# 1532  sym_MdPoNiIbHc  MNISymC3  10
# 1533  sym_MdPoNiIbHc  MNISymC3  10
# 1534  sym_MdPoNiIbHc  MNISymC3  10
# 1535  sym_MdPoNiIbHc  MNISymC3  10
#
#                                       train_data  train_loglik test_data  \
# 1200                                    ['Mdtb']  5.508969e+06      Mdtb
# 1201                                    ['Mdtb']  5.508969e+06      Mdtb
# 1202                                    ['Mdtb']  5.508969e+06      Mdtb
# 1203                                    ['Mdtb']  5.508969e+06      Mdtb
# 1204                                    ['Mdtb']  5.508969e+06      Mdtb
# ...                                          ...           ...       ...
# 1531  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07      Mdtb
# 1532  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07      Mdtb
# 1533  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07      Mdtb
# 1534  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07      Mdtb
# 1535  ['Mdtb' 'Pontine' 'Nishimoto' 'Ibc' 'Hcp']  1.780202e+07      Mdtb
#
#      indivtrain_ind  indivtrain_val  subj_num  dcbc_group  dcbc_indiv type
# 1200           half               1         0    0.069820    0.099068  sym
# 1201           half               1         1    0.085665    0.161238  sym
# 1202           half               1         2    0.041200    0.067237  sym
# 1203           half               1         3    0.189280    0.278620  sym
# 1204           half               1         4    0.117903    0.063467  sym
# ...             ...             ...       ...         ...         ...  ...
# 1531           half               2        19    0.107901    0.156388  sym
# 1532           half               2        20    0.136907    0.183305  sym
# 1533           half               2        21    0.057472    0.112531  sym
# 1534           half               2        22    0.025585    0.097281  sym
# 1535           half               2        23    0.089298    0.164211  sym
#
# [336 rows x 12 columns]

# %%
plt.figure(figsize=(15,8))
# sb.barplot(data=D.query( ' K == 10 '), x="test_data", y="dcbc_group", hue="train_data")
sb.barplot(data=D4.query( ' K == 10 & test_data == "Mdtb"  '), x="train_data", y="dcbc_group")
plt.ylim((0, 0.14))

plt.figure(figsize=(15,8))
sb.barplot(data=D.query( '  test_data == "Mdtb"  '), x="model_name", y="dcbc")
# Out:
# <AxesSubplot: xlabel='model_name', ylabel='dcbc'>
