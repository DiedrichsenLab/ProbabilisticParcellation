# %%
from pathlib import Path
import pandas as pd
import numpy as np
import nibabel as nb
import SUITPy as suit
import matplotlib.pyplot as plt
import seaborn as sb
import Functional_Fusion.atlas_map as am
from Functional_Fusion.dataset import *
import Functional_Fusion.matrix as matrix
import pickle
import sys
sys.path.append("..")
from evaluate import *

base_dir = '/Volumes/diedrichsen_data$/data/FunctionalFusion'
if not Path(base_dir).exists():
    base_dir = '/srv/diedrichsen/data/FunctionalFusion'

# %% [markdown]
# This notebook plots some of the different parcellations

# %% [markdown]
# ### Get the K=10 parcellations

# %%
model_name = ['asym_Md_space-MNISymC3_K-10',
                  'asym_Po_space-MNISymC3_K-10',
                  'asym_Ni_space-MNISymC3_K-10',
                  'asym_Ib_space-MNISymC3_K-10',
                  'asym_MdPoNiIb_space-MNISymC3_K-10']
fig = plt.figure(figsize=(20,10))
plot_parcel_flat_best(model_name,[2,3])

# %%
model_name = ['sym_Md_space-MNISymC3_K-10',
                  'sym_Po_space-MNISymC3_K-10',
                  'sym_Ni_space-MNISymC3_K-10',
                  'sym_Ib_space-MNISymC3_K-10',
                  'sym_MdPoNiIb_space-MNISymC3_K-10']
fig = plt.figure(figsize=(20,10))
plot_parcel_flat_best(model_name,[2,3])

# %%
model_name = ['asym_Md_space-MNISymC3_K-20',
                  'asym_Po_space-MNISymC3_K-20',
                  'asym_Ni_space-MNISymC3_K-20',
                  'asym_Ib_space-MNISymC3_K-20',
                  'asym_MdPoNiIb_space-MNISymC3_K-20']
fig = plt.figure(figsize=(20,10))
plot_parcel_flat_best(model_name,[2,3])

# %%
model_name = ['sym_Md_space-MNISymC3_K-20',
                  'sym_Po_space-MNISymC3_K-20',
                  'sym_Ni_space-MNISymC3_K-20',
                  'sym_Ib_space-MNISymC3_K-20',
                  'sym_MdPoNiIb_space-MNISymC3_K-20']
fig = plt.figure(figsize=(20,10))
plot_parcel_flat_best(model_name,[2,3])
