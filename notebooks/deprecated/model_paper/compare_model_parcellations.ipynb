# %%
from pathlib import Path
import pandas as pd
import numpy as np
import nibabel as nb
import SUITPy as suit
import matplotlib.pyplot as plt
import seaborn as sb
import Functional_Fusion.atlas_map as am
from Functional_Fusion.dataset import *
import Functional_Fusion.matrix as matrix
import HierarchBayesParcel.evaluation as ev
from ProbabilisticParcellation.util import *
import pickle
import sys
sys.path.append("..")

base_dir = '/Volumes/diedrichsen_data$/data/FunctionalFusion'
if not Path(base_dir).exists():
    base_dir = '/srv/diedrichsen/data/FunctionalFusion'

# %% [markdown]
# This notebook looks at the effect of using the different model types (uniform and nonuniform kappa, joint and disjoint session) on individual dataset parcellations

# %% [markdown]
# ## IBC only
# First row is session joint - Second row sessions seperately
# First Column is uniform Kappa - Second column in seperate kappa

# %%
model_name = ['Models_01/asym_Ib_space-MNISymC3_K-10',
                  'Models_02/asym_Ib_space-MNISymC3_K-10',
                  'Models_03/asym_Ib_space-MNISymC3_K-10',
                  'Models_04/asym_Ib_space-MNISymC3_K-10']
fig = plt.figure(figsize=(12,15))
plot_model_parcel(model_name,[1,4],align=True)

# %% [markdown]
# ## Nishimoto

# %% [markdown]
# ###

# %%
model_name = ['Models_01/asym_Ni_space-MNISymC3_K-10',
                  'Models_02/asym_Ni_space-MNISymC3_K-10',
                  'Models_04/asym_Ni_space-MNISymC3_K-10']
fig = plt.figure(figsize=(12,15))
plot_model_parcel(model_name,[1,3],align=True)

# %% [markdown]
# ## MDTB Dataste only

# %%
model_name = ['Models_01/asym_Md_space-MNISymC3_K-10',
                  'Models_02/asym_Md_space-MNISymC3_K-10',
                  'Models_04/asym_Md_space-MNISymC3_K-10']
fig = plt.figure(figsize=(12,15))
plot_model_parcel(model_name,[1,3],align=True)

# %% [markdown]
# ## Pontine only

# %%
model_name = ['Models_01/asym_Po_space-MNISymC3_K-10',
                  'Models_02/asym_Po_space-MNISymC3_K-10',
                  'Models_04/asym_Po_space-MNISymC3_K-10']
fig = plt.figure(figsize=(12,15))
plot_model_parcel(model_name,[1,3],align=True)

# %% [markdown]
# ## HCP only

# %%
model_name = ['Models_01/asym_Hc_space-MNISymC3_K-10',
                  'Models_02/asym_Hc_space-MNISymC3_K-10',
                  'Models_04/asym_Hc_space-MNISymC3_K-10']
fig = plt.figure(figsize=(12,15))
plot_model_parcel(model_name,[1,3],align=True)

# %% [markdown]
# ## Merged datasets

# %%
model_name = ['Models_01/asym_MdPoNiIb_space-MNISymC3_K-10',
                  'Models_04/asym_MdPoNiIb_space-MNISymC3_K-10']
fig = plt.figure(figsize=(12,15))
plot_model_parcel(model_name,[1,3],align=True)
