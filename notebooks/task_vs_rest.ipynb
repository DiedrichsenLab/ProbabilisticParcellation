# %% [markdown]
# # Task vs Rest-based parcellations
# This notebook shows results for symmetric models that include the HCP resting-state data into the training data, or don't include it.

# %%
import sys
sys.path.append("..")
from ProbabilisticParcellation.evaluate_da import *
from ProbabilisticParcellation.util import *
from Functional_Fusion.dataset import * 
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sb
import pandas as pd

# %% [markdown]
# ### Symmetric

# %% [markdown]
# ## All datasets fusion tested on individual datasets

# %%
_, colors_info = get_parcel('MNISymC3', parcel_name='MDTB10')
colors = np.zeros((1,3))
colors = np.vstack((colors, colors_info))
models = ['Models_03/sym_MdPoNiIbWmDeSo_space-MNISymC3_K-10',
          'Models_03/sym_MdPoNiIbWmDeSoHc_space-MNISymC3_K-10',
          'Models_03/sym_Md_space-MNISymC3_K-10',
          'Models_03/sym_Hc_space-MNISymC3_K-10']

plt.figure(figsize=(20, 20))
plot_model_parcel(models, [2,2], cmap=colors, align=True)

# %%
models = ['Models_03/sym_MdPoNiIbWmDeSo_space-MNISymC3_K-20',
          'Models_03/sym_MdPoNiIbWmDeSoHc_space-MNISymC3_K-20',
          'Models_03/sym_Md_space-MNISymC3_K-20',
          'Models_03/sym_Hc_space-MNISymC3_K-20']

plt.figure(figsize=(20, 10))
plot_model_parcel(models, [2,2], cmap='tab20', align=True)

# %%
cmap = matplotlib.cm.get_cmap('Spectral')
colors = cmap(np.linspace(0,1,35))

models = ['Models_03/sym_MdPoNiIbWmDeSo_space-MNISymC3_K-34',
          'Models_03/sym_MdPoNiIbWmDeSoHc_space-MNISymC3_K-34',
          'Models_03/sym_Md_space-MNISymC3_K-34',
          'Models_03/sym_Hc_space-MNISymC3_K-34']

plt.figure(figsize=(20, 10))
plot_model_parcel(models, [2,2], cmap='tab20', align=True)

# %%
cmap = matplotlib.cm.get_cmap('Spectral')
colors = cmap(np.linspace(0,1,35))

models = ['Models_03/sym_MdPoNiIbWmDeSo_space-MNISymC3_K-40',
          'Models_03/sym_MdPoNiIbWmDeSoHc_space-MNISymC3_K-40',
          'Models_03/sym_Md_space-MNISymC3_K-40',
          'Models_03/sym_Hc_space-MNISymC3_K-40']

plt.figure(figsize=(20, 10))
plot_model_parcel(models, [2,2], cmap='tab20', align=True)

# %%
cmap = matplotlib.cm.get_cmap('Spectral')
colors = cmap(np.linspace(0,1,35))

models = ['Models_03/sym_MdPoNiIbWmDeSo_space-MNISymC3_K-68',
          'Models_03/sym_MdPoNiIbWmDeSoHc_space-MNISymC3_K-68',
          'Models_03/sym_Md_space-MNISymC3_K-68',
          'Models_03/sym_Hc_space-MNISymC3_K-68']

plt.figure(figsize=(20, 10))
plot_model_parcel(models, [2,2], cmap='tab20', align=True)

# %%
cmap = matplotlib.cm.get_cmap('Spectral')
colors = cmap(np.linspace(0,1,35))

models = ['Models_03/sym_MdPoNiIbWmDeSo_space-MNISymC3_K-80',
          'Models_03/sym_MdPoNiIbWmDeSoHc_space-MNISymC3_K-80',
          'Models_03/sym_Md_space-MNISymC3_K-80',
          'Models_03/sym_Hc_space-MNISymC3_K-80']

plt.figure(figsize=(20, 10))
plot_model_parcel(models, [2,2], cmap='tab20', align=True)
